# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/karenrugerio/Desktop/Reto/train_data.csv')
print(df)
# Out:
#                                                customer_ID         S_2  \
# 0        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09
# 1        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07
# 2        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28
# 3        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13
# 4        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16
# ...                                                    ...         ...
# 5531446  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2017-11-05
# 5531447  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2017-12-23
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-01-06
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-02-06
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-03-14
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# ...

# %%
delinquency = [x for x in df if x.startswith("D")]
spend = [x for x in df if x.startswith("S")]
payment = [x for x in df if x.startswith("P")]
balance = [x for x in df if x.startswith("B")]
risk = [x for x in df if x.startswith("R")]

# %%
pd.set_option('display.max_rows', None)
per = (df.isna().sum() / 5531451 ) * 100
per
# Out:
# customer_ID     0.000000
# S_2             0.000000
# P_2             0.831337
# D_39            0.000000
# B_1             0.000000
# B_2             0.036446
# R_1             0.000000
# S_3            18.449843
# D_41            0.036446
# B_3             0.036446
# D_42           85.694278
# D_43           29.981211
# D_44            4.959259
# B_4             0.000000
# D_45            0.036464
# B_5             0.000000
# R_2             0.000000
# D_46           21.905627
# D_47            0.000000
# D_48           12.993426
# D_49           90.137597
# B_6             0.004212
# B_7             0.000000
# B_8             0.402571
# D_50           56.809723
# D_51            0.000000
# B_9             0.000000
# R_3             0.000000
# D_52            0.534453
# P_3             5.450505
# B_10            0.000000
# D_53           73.842921
# S_5             0.000000
# B_11            0.000000
# S_6             0.000000
# D_54            0.036446
# R_4             0.000000
# ...
